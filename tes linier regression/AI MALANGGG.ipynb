# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/PyAi/tes linier regression/tplink dataset.csv', sep=';')
df.head()
# Out:
#            Date Last Crawling   SKU Name  \
# 0  Oct 22, 2022  Oct 22, 2022  TL WR840N
# 1  Oct 22, 2022  Oct 22, 2022  TL WR840N
# 2  Oct 22, 2022  Oct 22, 2022  TL WR840N
# 3  Oct 22, 2022  Oct 22, 2022  TL WR840N
# 4  Oct 22, 2022  Oct 22, 2022  TL WR840N
#
#                                         Product Name  \
# 0  TP-Link TL-WR840N 2 Antenna 300Mbps Wireless N...
# 1  Promo TP-LINK TL-WR840N Wireless Router 300Mbp...
# 2  Tp-Link TL-WR840N 300Mbps Wireless N Speed Rou...
# 3  JARINGAN TP-LINK TL-WR 840N TL-WR840N 300MBps ...
# 4  TPLink TL-WR840N Router Wireless WiFi 300Mbps ...
#
#                                          Url Product        Seller   Merchant  \
# 0  https://tokopedia.com/ccplace/tp-link-tl-wr840...  ccplace shop  tokopedia
# 1  https://tokopedia.com/gilsaashopp/promo-tp-lin...  gilsaa_shopp  tokopedia
# 2  https://tokopedia.com/ccwinta/tp-link-tl-wr840...  ccwinta shop  tokopedia
# ...

# %%
#untuk mengetahui bentuk dataset, berapa kolom dan berapa baris
df.shape
# Out:
# (27794, 18)

# %%
#untuk mengetahui data yang memiliki missing value
df.isnull().sum()
# Out:
# Date              25785
# Last Crawling     25785
# SKU Name          25785
# Product Name      25785
# Url Product       25785
# Seller            25785
# Merchant          25785
# Stock             25785
# Item Condition    25785
# Filter            25785
# Flag              25785
# Bottom Price      25785
# Original Price    25785
# Discount          25785
# Selling Price     25785
# Discrepancy       25785
# Sales Quantity    25785
# Sales Revenue     25785
# dtype: int64

# %%
#menghapus missing value agar tidak membingungkan ketika data telah dicoba
df.dropna()
# Out:
#               Date Last Crawling   SKU Name  \
# 0     Oct 22, 2022  Oct 22, 2022  TL WR840N
# 1     Oct 22, 2022  Oct 22, 2022  TL WR840N
# 2     Oct 22, 2022  Oct 22, 2022  TL WR840N
# 3     Oct 22, 2022  Oct 22, 2022  TL WR840N
# 4     Oct 22, 2022  Oct 22, 2022  TL WR840N
# ...            ...           ...        ...
# 2004  Oct 15, 2022  Oct 15, 2022  TL WR840N
# 2005  Oct 15, 2022  Oct 15, 2022  TL WR840N
# 2006  Oct 15, 2022  Oct 15, 2022  TL WR840N
# 2007  Oct 15, 2022  Oct 15, 2022  TL WR840N
# 2008  Oct 15, 2022  Oct 15, 2022  TL WR840N
#
#                                            Product Name  \
# 0     TP-Link TL-WR840N 2 Antenna 300Mbps Wireless N...
# 1     Promo TP-LINK TL-WR840N Wireless Router 300Mbp...
# 2     Tp-Link TL-WR840N 300Mbps Wireless N Speed Rou...
# 3     JARINGAN TP-LINK TL-WR 840N TL-WR840N 300MBps ...
# 4     TPLink TL-WR840N Router Wireless WiFi 300Mbps ...
# ...                                                 ...
# ...

# %%
#mengetahui data yang duplikatt
df.duplicated().sum()
# Out:
# np.int64(25784)

# %%
#hapus data duplikat
df.drop_duplicates()
# Out:
#               Date Last Crawling   SKU Name  \
# 0     Oct 22, 2022  Oct 22, 2022  TL WR840N
# 1     Oct 22, 2022  Oct 22, 2022  TL WR840N
# 2     Oct 22, 2022  Oct 22, 2022  TL WR840N
# 3     Oct 22, 2022  Oct 22, 2022  TL WR840N
# 4     Oct 22, 2022  Oct 22, 2022  TL WR840N
# ...            ...           ...        ...
# 2005  Oct 15, 2022  Oct 15, 2022  TL WR840N
# 2006  Oct 15, 2022  Oct 15, 2022  TL WR840N
# 2007  Oct 15, 2022  Oct 15, 2022  TL WR840N
# 2008  Oct 15, 2022  Oct 15, 2022  TL WR840N
# 2009           NaN           NaN        NaN
#
#                                            Product Name  \
# 0     TP-Link TL-WR840N 2 Antenna 300Mbps Wireless N...
# 1     Promo TP-LINK TL-WR840N Wireless Router 300Mbp...
# 2     Tp-Link TL-WR840N 300Mbps Wireless N Speed Rou...
# 3     JARINGAN TP-LINK TL-WR 840N TL-WR840N 300MBps ...
# 4     TPLink TL-WR840N Router Wireless WiFi 300Mbps ...
# ...                                                 ...
# ...

# %%
#melihat list kolom
df.columns.tolist()
# Out:
# ['Date',
#  'Last Crawling',
#  'SKU Name',
#  'Product Name',
#  'Url Product',
#  'Seller',
#  'Merchant',
#  'Stock',
#  'Item Condition',
#  'Filter',
#  'Flag',
#  'Bottom Price',
#  'Original Price',
#  'Discount',
#  'Selling Price',
#  'Discrepancy',
#  'Sales Quantity',
#  'Sales Revenue']

# %%
#melihat nilai unik dari atribut SKU Name
df['SKU Name'].unique()
# Out:
# <StringArray>
# ['TL WR840N', nan]
# Length: 2, dtype: str

# %%
df['Url Product'].unique()
# Out:
# <StringArray>
# [                                 'https://tokopedia.com/ccplace/tp-link-tl-wr840n-2-antenna-300mbps-wireless-n-router',
#                              'https://tokopedia.com/gilsaashopp/promo-tp-link-tl-wr840n-wireless-router-300mbps-diskon',
#                   'https://tokopedia.com/ccwinta/tp-link-tl-wr840n-300mbps-wireless-n-speed-router-wifi-840-840n-wr840',
#                           'https://tokopedia.com/belsa/jaringan-tp-link-tl-wr-840n-tl-wr840n-300mbps-wireless-router-2',
#                   'https://tokopedia.com/ccwinta/tplink-tl-wr840n-router-wireless-wifi-300mbps-2-antena-tp-link-wr840n',
#                               'https://tokopedia.com/garwitastore-i/tp-link-tl-wr840n-antenna-300mbps-wireless-n-promo',
#                                                                'https://tokopedia.com/ccplace/tp-link-wr840n-tl-wr840n',
#                   'https://tokopedia.com/nugrahaabadi123/tp-link-tl-wr840n-300mbps-tplink-wifi-wireless-n-router-wr840',
# ...

# %%
df.drop(columns=['Date', 'Seller', 'Merchant', 'Stock', 'Item Condition', 'Filter', 'Flag', 'Discount', 'Discrepancy', 'Sales Quantity', 'Sales Revenue'], inplace=True)

# %%
df.columns.tolist()
# Out:
# ['Last Crawling',
#  'SKU Name',
#  'Product Name',
#  'Url Product',
#  'Bottom Price',
#  'Original Price',
#  'Selling Price']

# %%
df
# Out:
#       Last Crawling   SKU Name  \
# 0      Oct 22, 2022  TL WR840N
# 1      Oct 22, 2022  TL WR840N
# 2      Oct 22, 2022  TL WR840N
# 3      Oct 22, 2022  TL WR840N
# 4      Oct 22, 2022  TL WR840N
# ...             ...        ...
# 27789           NaN        NaN
# 27790           NaN        NaN
# 27791           NaN        NaN
# 27792           NaN        NaN
# 27793           NaN        NaN
#
#                                             Product Name  \
# 0      TP-Link TL-WR840N 2 Antenna 300Mbps Wireless N...
# 1      Promo TP-LINK TL-WR840N Wireless Router 300Mbp...
# 2      Tp-Link TL-WR840N 300Mbps Wireless N Speed Rou...
# 3      JARINGAN TP-LINK TL-WR 840N TL-WR840N 300MBps ...
# 4      TPLink TL-WR840N Router Wireless WiFi 300Mbps ...
# ...                                                  ...
# 27789                                                NaN
# 27790                                                NaN
# 27791                                                NaN
# ...

# %%
df.dropna()
# Out:
#      Last Crawling   SKU Name  \
# 0     Oct 22, 2022  TL WR840N
# 1     Oct 22, 2022  TL WR840N
# 2     Oct 22, 2022  TL WR840N
# 3     Oct 22, 2022  TL WR840N
# 4     Oct 22, 2022  TL WR840N
# ...            ...        ...
# 2004  Oct 15, 2022  TL WR840N
# 2005  Oct 15, 2022  TL WR840N
# 2006  Oct 15, 2022  TL WR840N
# 2007  Oct 15, 2022  TL WR840N
# 2008  Oct 15, 2022  TL WR840N
#
#                                            Product Name  \
# 0     TP-Link TL-WR840N 2 Antenna 300Mbps Wireless N...
# 1     Promo TP-LINK TL-WR840N Wireless Router 300Mbp...
# 2     Tp-Link TL-WR840N 300Mbps Wireless N Speed Rou...
# 3     JARINGAN TP-LINK TL-WR 840N TL-WR840N 300MBps ...
# 4     TPLink TL-WR840N Router Wireless WiFi 300Mbps ...
# ...                                                 ...
# 2004                  Wireless Router TP-Link TL-WR840N
# 2005    Tp-Link / Tplink Tl-Wr840N Wireless-N300 Router
# 2006  TP-Link / TPLink TL-WR840N Wireless-N300 Route...
# ...

# %%
plt = figure add_subplot(figsize=(10,4))
add_subplot(1,2,1)
plt.(df(['SKU Name']), kind="kde")
add_subplot(1,2,2)
plt.show()
# Out:
#   Cell In[174], line 1
#     plt = figure add_subplot(figsize=(10,4))
#                  ^
# SyntaxError: invalid syntax
