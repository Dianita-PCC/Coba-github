# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/PyAi/Smartphone.csv')
df.head()
# Out:
#   User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1   58    Male    Professional     Android                1.3
# 1      U2   25    Male    Professional     Android                1.2
# 2      U3   19    Male         Student         iOS                5.3
# 3      U4   35  Female  Business Owner         iOS                5.8
# 4      U5   33    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8             4
# 1                 1.5                        5          6.4             1
# 2                 5.7                        5          9.0             4
# 3                 2.5                        2          5.7             3
# 4                 1.3                        4          5.7             3
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# 0               42                     1                        8.7
# 1               51                     3                        5.1
# 2               14                     5                        6.3
# 3               36                     6                       12.8
# 4               37                     5                        9.9

# %%
df.columns.tolist()
# Out:
# ['User_ID',
#  'Age',
#  'Gender',
#  'Occupation',
#  'Device_Type',
#  'Daily_Phone_Hours',
#  'Social_Media_Hours',
#  'Work_Productivity_Score',
#  'Sleep_Hours',
#  'Stress_Level',
#  'App_Usage_Count',
#  'Caffeine_Intake_Cups',
#  'Weekend_Screen_Time_Hours']

# %%
cat_cols=['Age','Gender','Occupation','Device_Type']

for col in cat_cols:
    labels = df[col].dropna().unique()
    mapping = {label: i for i , label in enumerate(labels)}
    df[col] = df[col].map(mapping
# Out:
#   Cell In[34], line 6
#     df[col] = df[col].map(mapping
#                                  ^
# _IncompleteInputError: incomplete input

# %%
df
# Out:
#       User_ID  Age  Gender  Occupation  Device_Type  Daily_Phone_Hours  \
# 0          U1    0       0           0            0                1.3
# 1          U2    1       0           0            0                1.2
# 2          U3    2       0           1            1                5.3
# 3          U4    3       1           2            1                5.8
# 4          U5    4       0           3            0                7.9
# ...       ...  ...     ...         ...          ...                ...
# 49995  U49996   19       0           2            0                5.9
# 49996  U49997   25       2           2            0                2.9
# 49997  U49998   24       1           3            1                1.4
# 49998  U49999   31       1           2            1                8.9
# 49999  U50000   20       2           3            0                8.8
#
#        Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                     6.7                        6          8.8             4
# 1                     1.5                        5          6.4             1
# 2                     5.7                        5          9.0             4
# 3                     2.5                        2          5.7             3
# 4                     1.3                        4          5.7             3
# ...                   ...                      ...          ...           ...
# 49995                 5.4                        5          6.6             1
# 49996                 7.4                        9          6.3             2
# 49997                 2.5                        4          6.7             9
# 49998                 3.0                        6          5.5             2
# 49999                 2.8                        3          5.4             1
#
#        App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# 0                   42                     1                        8.7
# 1                   51                     3                        5.1
# 2                   14                     5                        6.3
# 3                   36                     6                       12.8
# 4                   37                     5                        9.9
# ...                ...                   ...                        ...
# 49995               11                     5                        3.0
# 49996               20                     4                        6.2
# 49997               39                     4                        5.1
# 49998               51                     0                        9.2
# 49999               54                     5                        6.9
#
# [50000 rows x 13 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Occupation                   0
# Device_Type                  0
# Daily_Phone_Hours            0
# Social_Media_Hours           0
# Work_Productivity_Score      0
# Sleep_Hours                  0
# Stress_Level                 0
# App_Usage_Count              0
# Caffeine_Intake_Cups         0
# Weekend_Screen_Time_Hours    0
# dtype: int64

# %%
corr = df.corr(numeric_only=True)
corr['Stress_Level'].sort_values(ascending=False)
# Out:
# Stress_Level                 1.000000
# Work_Productivity_Score      0.009786
# Sleep_Hours                  0.004691
# Weekend_Screen_Time_Hours    0.002671
# Caffeine_Intake_Cups         0.001718
# Gender                      -0.000521
# App_Usage_Count             -0.001272
# Social_Media_Hours          -0.002721
# Daily_Phone_Hours           -0.002762
# Device_Type                 -0.002858
# Occupation                  -0.004072
# Age                         -0.005601
# Name: Stress_Level, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['Stress_Level'], df['Caffeine_Intake_Cups'])
ax.set_xlabel('Stress_Level')
ax.set_ylabel('Weekend_Screen_Time_Hours')
plt.show()

# %%
plt.figure(figsize=(15,5))
c = df.corr(numeric_only=True)
sns.heatmap(c, cmap="RdYlGn", annot=True)
c
# Out:
#                                 Age    Gender  Occupation  Device_Type  \
# Age                        1.000000  0.002389    0.000312    -0.002934
# Gender                     0.002389  1.000000    0.006194     0.007073
# Occupation                 0.000312  0.006194    1.000000    -0.002168
# Device_Type               -0.002934  0.007073   -0.002168     1.000000
# Daily_Phone_Hours         -0.000848 -0.003619    0.004487    -0.006764
# Social_Media_Hours         0.001868  0.005113    0.008965    -0.000096
# Work_Productivity_Score   -0.000295  0.002947   -0.001397    -0.010682
# Sleep_Hours                0.000513 -0.008443   -0.008376     0.002101
# Stress_Level              -0.005601 -0.000521   -0.004072    -0.002858
# App_Usage_Count           -0.003349  0.001322    0.005738    -0.000003
# Caffeine_Intake_Cups      -0.003123  0.012411    0.003871    -0.008016
# Weekend_Screen_Time_Hours  0.001970 -0.003717   -0.002599     0.000800
#
#                            Daily_Phone_Hours  Social_Media_Hours  \
# Age                                -0.000848            0.001868
# Gender                             -0.003619            0.005113
# Occupation                          0.004487            0.008965
# Device_Type                        -0.006764           -0.000096
# Daily_Phone_Hours                   1.000000            0.000591
# Social_Media_Hours                  0.000591            1.000000
# Work_Productivity_Score            -0.002404            0.003625
# Sleep_Hours                        -0.003434           -0.000871
# Stress_Level                       -0.002762           -0.002721
# App_Usage_Count                     0.004670            0.001831
# Caffeine_Intake_Cups                0.006465            0.009161
# Weekend_Screen_Time_Hours          -0.003123           -0.008570
#
#                            Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# Age                                      -0.000295     0.000513     -0.005601
# Gender                                    0.002947    -0.008443     -0.000521
# Occupation                               -0.001397    -0.008376     -0.004072
# Device_Type                              -0.010682     0.002101     -0.002858
# Daily_Phone_Hours                        -0.002404    -0.003434     -0.002762
# Social_Media_Hours                        0.003625    -0.000871     -0.002721
# Work_Productivity_Score                   1.000000     0.003243      0.009786
# Sleep_Hours                               0.003243     1.000000      0.004691
# Stress_Level                              0.009786     0.004691      1.000000
# App_Usage_Count                           0.001125     0.000999     -0.001272
# Caffeine_Intake_Cups                      0.001253     0.004251      0.001718
# Weekend_Screen_Time_Hours                -0.005343    -0.006457      0.002671
#
#                            App_Usage_Count  Caffeine_Intake_Cups  \
# Age                              -0.003349             -0.003123
# Gender                            0.001322              0.012411
# Occupation                        0.005738              0.003871
# Device_Type                      -0.000003             -0.008016
# Daily_Phone_Hours                 0.004670              0.006465
# Social_Media_Hours                0.001831              0.009161
# Work_Productivity_Score           0.001125              0.001253
# Sleep_Hours                       0.000999              0.004251
# Stress_Level                     -0.001272              0.001718
# App_Usage_Count                   1.000000             -0.000096
# Caffeine_Intake_Cups             -0.000096              1.000000
# Weekend_Screen_Time_Hours        -0.000530              0.002682
#
#                            Weekend_Screen_Time_Hours
# Age                                         0.001970
# Gender                                     -0.003717
# Occupation                                 -0.002599
# Device_Type                                 0.000800
# Daily_Phone_Hours                          -0.003123
# Social_Media_Hours                         -0.008570
# Work_Productivity_Score                    -0.005343
# Sleep_Hours                                -0.006457
# Stress_Level                                0.002671
# App_Usage_Count                            -0.000530
# Caffeine_Intake_Cups                        0.002682
# Weekend_Screen_Time_Hours                   1.000000

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['Stress_Level'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['Stress_Level'])
plt.show()

# %%
#MULTIPLE LINIER REGRESSION
X = df[["Work_Productivity_Score", "Sleep_Hours","Weekend_Screen_Time_Hours","Caffeine_Intake_Cups"]].to_numpy(dtype=float)
y = df[["Stress_Level"]].to_numpy(dtype=float)  # bentuk (n,1)

n = X.shape[0]
print("Shape X:", X.shape)
print("Shape y:", y.shape)
# Out:
# Shape X: (50000, 4)
# Shape y: (50000, 1)

# %%
# Tambahkan kolom 1 untuk intercept (bias)
X_b = np.c_[np.ones((n, 1)), X]  
print("Shape X_b:", X_b.shape)
# Out:
# Shape X_b: (50000, 5)

# %%
# Hitung koefisien beta pakai Normal Equation: Normal Equation adalah rumus matematika yang digunakan untuk menghitung parameter terbaik pada regresi linear tanpa proses iterasi (tanpa gradient descent).
# beta = (X^T X)^(-1) X^T y
beta = np.linalg.inv(X_b.T @ X_b) @ (X_b.T @ y)

b0, b1, b2, b3, b4 = beta.flatten()
print("Intercept (b0):", b0)
print("Koef work_productivity_score (b1):", b1)
print("Koef sleep_hours (b2):", b2)
print("Koef weekend_screen_time_hours (b3):", b3)
print("Koef caffeine_intake_cups (b4):", b4)


print(f"\nPersamaan: Ŷ = {b0:.6f} + {b1:.6f}*(work_productivity_score) + {b2:.6f}*(sleep_hours) + {b3:.6f}*(weekend_screen_time_hours)+ {b4:.6f}*(weekend_screen_time_hours) + {b3:.6f}*(caffeine_intake_cups)")
# Out:
# Intercept (b0): 5.365108911308113
# Koef work_productivity_score (b1): 0.009771121722844176
# Koef sleep_hours (b2): 0.009250284461778132
# Koef weekend_screen_time_hours (b3): 0.002279865174617874
# Koef caffeine_intake_cups (b4): 0.0024138730353566603
#
# Persamaan: Ŷ = 5.365109 + 0.009771*(work_productivity_score) + 0.009250*(sleep_hours) + 0.002280*(weekend_screen_time_hours)+ 0.002414*(weekend_screen_time_hours) + 0.002280*(caffeine_intake_cups)

# %%
# Prediksi
y_pred = X_b @ beta  # (n,1)
residual = y - y_pred

# %%
# Fungsi evaluasi
def mae(y_true, y_hat):
    return float(np.mean(np.abs(y_true - y_hat)))

def mse(y_true, y_hat):
    return float(np.mean((y_true - y_hat) ** 2))

def rmse(y_true, y_hat):
    return float(np.sqrt(mse(y_true, y_hat)))

def r2_score(y_true, y_hat):
    y_true = np.asarray(y_true)
    y_hat = np.asarray(y_hat)
    sst = np.sum((y_true - np.mean(y_true)) ** 2)
    sse = np.sum((y_true - y_hat) ** 2)
    return float(1 - (sse / sst))

# %%
mae_val = mae(y, y_pred)
mse_val = mse(y, y_pred)
rmse_val = rmse(y, y_pred)
r2_val = r2_score(y, y_pred)

print("MAE:", mae_val)
print("MSE:", mse_val)
print("RMSE:", rmse_val)
print("R-squared:", r2_val)
# Out:
# MAE: 2.4965932049397463
# MSE: 8.241965621464178
# RMSE: 2.8708823768075518
# R-squared: 0.00012788135510899412

# %%
# Lihat hasil prediksi + residu dalam tabel
out = df.copy()
out["pred_stress_level"] = y_pred.flatten()
out["residu"] = (y - y_pred).flatten()

print(out.head(10))
# Out:
#   User_ID  Age  Gender  Occupation  Device_Type  Daily_Phone_Hours  \
# 0      U1    0       0           0            0                1.3
# 1      U2    1       0           0            0                1.2
# 2      U3    2       0           1            1                5.3
# 3      U4    3       1           2            1                5.8
# 4      U5    4       0           3            0                7.9
# 5      U6    5       1           1            0               10.9
# 6      U7    6       0           1            1                5.6
# 7      U8    7       0           3            1                8.5
# 8      U9    8       1           2            0                9.4
# 9     U10    9       1           1            1                2.8
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8             4
# 1                 1.5                        5          6.4             1
# 2                 5.7                        5          9.0             4
# 3                 2.5                        2          5.7             3
# 4                 1.3                        4          5.7             3
# 5                 4.2                        9          6.3             7
# 6                 6.1                        8          6.7             3
# 7                 1.9                        4          7.8             3
# 8                 2.5                        3          6.4             4
# 9                 1.1                        1          4.5             2
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours  \
# 0               42                     1                        8.7
# 1               51                     3                        5.1
# 2               14                     5                        6.3
# 3               36                     6                       12.8
# 4               37                     5                        9.9
# 5               34                     5                        3.6
# 6                5                     3                        2.9
# 7                6                     6                       12.8
# 8               17                     3                        3.1
# 9                7                     0                        2.7
#
#    pred_stress_level    residu
# 0           5.527387 -1.527387
# 1           5.492035 -4.492035
# 2           5.523650 -1.523650
# 3           5.481043 -2.481043
# 4           5.491560 -2.491560
# 5           5.531603  1.468397
# 6           5.519108 -2.519108
# 7           5.520011 -2.520011
# 8           5.467933 -1.467933
# 9           5.422662 -3.422662

# %%
# Plot: Actual vs Predicted
plt.scatter(out["Stress_Level"], out["pred_stress_level"])
plt.title("Actual vs Predicted")
plt.xlabel("Stress actual")
plt.ylabel("Stress prediksi")
plt.show()

# %%
out['pred_stress_level_norm'] = (
    out['pred_stress_level'] - out['pred_stress_level'].min()
) / (
    out['pred_stress_level'].max() - out['pred_stress_level'].min()
)

# %%
out.head()
# Out:
#   User_ID  Age  Gender  Occupation  Device_Type  Daily_Phone_Hours  \
# 0      U1    0       0           0            0                1.3
# 1      U2    1       0           0            0                1.2
# 2      U3    2       0           1            1                5.3
# 3      U4    3       1           2            1                5.8
# 4      U5    4       0           3            0                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8             4
# 1                 1.5                        5          6.4             1
# 2                 5.7                        5          9.0             4
# 3                 2.5                        2          5.7             3
# 4                 1.3                        4          5.7             3
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours  \
# 0               42                     1                        8.7
# 1               51                     3                        5.1
# 2               14                     5                        6.3
# 3               36                     6                       12.8
# 4               37                     5                        9.9
#
#    pred_stress_level    residu  pred_stress_level_norm KategoriStress
# 0           5.527387 -1.527387                0.635764         tinggi
# 1           5.492035 -4.492035                0.428451         sedang
# 2           5.523650 -1.523650                0.613848         tinggi
# 3           5.481043 -2.481043                0.363990         rendah
# 4           5.491560 -2.491560                0.425664         sedang

# %%
bins = [0,0.2,0.4,0.6,0.8,1]

labels = [
'sangat rendah',
'rendah',
'sedang',
'tinggi',
'sangat tinggi'
]

out['KategoriStress'] = pd.cut(out['pred_stress_level_norm'], bins=bins, labels=labels)

# %%
out[['pred_stress_level_norm', 'KategoriStress']].head(10)
# Out:
#    pred_stress_level_norm KategoriStress
# 0                0.635764         tinggi
# 1                0.428451         sedang
# 2                0.613848         tinggi
# 3                0.363990         rendah
# 4                0.425664         sedang
# 5                0.660487         tinggi
# 6                0.587214         sedang
# 7                0.592511         sedang
# 8                0.287109         rendah
# 9                0.021622  sangat rendah

# %%
out
# Out:
#       User_ID  Age  Gender  Occupation  Device_Type  Daily_Phone_Hours  \
# 0          U1    0       0           0            0                1.3
# 1          U2    1       0           0            0                1.2
# 2          U3    2       0           1            1                5.3
# 3          U4    3       1           2            1                5.8
# 4          U5    4       0           3            0                7.9
# ...       ...  ...     ...         ...          ...                ...
# 49995  U49996   19       0           2            0                5.9
# 49996  U49997   25       2           2            0                2.9
# 49997  U49998   24       1           3            1                1.4
# 49998  U49999   31       1           2            1                8.9
# 49999  U50000   20       2           3            0                8.8
#
#        Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                     6.7                        6          8.8             4
# 1                     1.5                        5          6.4             1
# 2                     5.7                        5          9.0             4
# 3                     2.5                        2          5.7             3
# 4                     1.3                        4          5.7             3
# ...                   ...                      ...          ...           ...
# 49995                 5.4                        5          6.6             1
# 49996                 7.4                        9          6.3             2
# 49997                 2.5                        4          6.7             9
# 49998                 3.0                        6          5.5             2
# 49999                 2.8                        3          5.4             1
#
#        App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours  \
# 0                   42                     1                        8.7
# 1                   51                     3                        5.1
# 2                   14                     5                        6.3
# 3                   36                     6                       12.8
# 4                   37                     5                        9.9
# ...                ...                   ...                        ...
# 49995               11                     5                        3.0
# 49996               20                     4                        6.2
# 49997               39                     4                        5.1
# 49998               51                     0                        9.2
# 49999               54                     5                        6.9
#
#        pred_stress_level    residu  pred_stress_level_norm KategoriStress
# 0               5.527387 -1.527387                0.635764         tinggi
# 1               5.492035 -4.492035                0.428451         sedang
# 2               5.523650 -1.523650                0.613848         tinggi
# 3               5.481043 -2.481043                0.363990         rendah
# 4               5.491560 -2.491560                0.425664         sedang
# ...                  ...       ...                     ...            ...
# 49995           5.493925 -4.493925                0.439535         sedang
# 49996           5.535116 -3.535116                0.681093         tinggi
# 49997           5.487453  3.512547                0.401579         sedang
# 49998           5.495587 -3.495587                0.449279         sedang
# 49999           5.472174 -4.472174                0.311979         rendah
#
# [50000 rows x 17 columns]
