# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tkinter as tk

# %%
df = pd.read_csv('/PyAi/dataset_kredit_lengkap.csv', sep=';')
df.head()
# Out:
#    ID  Usia Jenis_Kelamin Status_Pernikahan Pendidikan  Jumlah_Anak  \
# 0   1    50     Perempuan            Lajang         S1            1
# 1   2    31     Perempuan           Menikah         S1            2
# 2   3    39     Laki-laki            Lajang         S1            4
# 3   4    20     Perempuan            Lajang        SMA            1
# 4   5    56     Perempuan           Menikah        SMP            4
#
#       Wilayah Jenis_Pekerjaan  Lama_Bekerja_Tahun  Pendapatan_Bulanan  ...  \
# 0    Sumatera       Wirausaha                12.0           3836309.0  ...
# 1  Kalimantan       Wirausaha                23.0           4378078.0  ...
# 2    Sumatera       Wirausaha                34.0          10273812.0  ...
# 3  Kalimantan          Swasta                23.0          14368148.0  ...
# 4    Sulawesi             PNS                11.0          10295732.0  ...
#
#     Nilai_Aset  Hutang_Existing  Kepemilikan_Rumah     Riwayat_Kredit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1010 non-null   int64
#  1   Usia                     1010 non-null   int64
#  2   Jenis_Kelamin            1010 non-null   str
#  3   Status_Pernikahan        1010 non-null   str
#  4   Pendidikan               1010 non-null   str
#  5   Jumlah_Anak              1010 non-null   int64
#  6   Wilayah                  1010 non-null   str
#  7   Jenis_Pekerjaan          1010 non-null   str
#  8   Lama_Bekerja_Tahun       968 non-null    float64
#  9   Pendapatan_Bulanan       980 non-null    float64
#  10  Pengeluaran_Bulanan      1010 non-null   int64
#  11  Nilai_Aset               980 non-null    float64
#  12  Hutang_Existing          942 non-null    float64
#  13  Kepemilikan_Rumah        1010 non-null   str
# ...

# %%
df.isnull().sum()
# Out:
# ID                          0
# Usia                        0
# Jenis_Kelamin               0
# Status_Pernikahan           0
# Pendidikan                  0
# Jumlah_Anak                 0
# Wilayah                     0
# Jenis_Pekerjaan             0
# Lama_Bekerja_Tahun         42
# Pendapatan_Bulanan         30
# Pengeluaran_Bulanan         0
# Nilai_Aset                 30
# Hutang_Existing            68
# Kepemilikan_Rumah           0
# Riwayat_Kredit              0
# Skor_Kesehatan_Keuangan    30
# Jumlah_Rekening             0
# Tujuan_Pinjaman             0
# Jumlah_Pinjaman             0
# Tenor_Bulan                 0
# Layak_Kredit                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Jenis_Kelamin'].unique()
# Out:
# <StringArray>
# ['Perempuan', 'Laki-laki', 'L', 'laki-laki', 'LAKI-LAKI']
# Length: 5, dtype: str
