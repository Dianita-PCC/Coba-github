# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/PyAi/house prices.csv')
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.shape
# Out:
# (1460, 81)

# %%
df['LotArea'].shape
# Out:
# (1460,)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.dropna()
df.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
#                  ...
# MoSold           1460
# YrSold           1460
# SaleType         1460
# SaleCondition    1460
# SalePrice        1460
# Length: 81, dtype: int64

# %%
df.drop(columns=['Id', 'MSSubClass', 'LotFrontage', 'OverallQual', 'OverallCond', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'RoofMatl', 'Exterior1st', 'Exterior2nd'], inplace=True)

# %%
df.shape
# Out:
# (1460, 64)

# %%
df.drop(columns=['LandContour','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','HeatingQC','CentralAir','Electrical','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','TotRmsAbvGrd','Functional','Fireplaces','FireplaceQu','GarageType','GarageYrBlt'], inplace=True)

# %%
df.drop(columns=['GarageFinish','GarageCars','GarageArea','GarageQual','GarageCond','PavedDrive','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','PoolQC','Fence','MiscFeature','MiscVal','YrSold','MoSold','SaleType','SaleCondition'], inplace=True)

# %%
df.drop(columns=['PoolArea','ScreenPorch','Alley','Heating','KitchenQual'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MSZoning      1460 non-null   str
#  1   LotArea       1460 non-null   int64
#  2   Street        1460 non-null   str
#  3   LotShape      1460 non-null   str
#  4   Utilities     1460 non-null   str
#  5   HouseStyle    1460 non-null   str
#  6   YearBuilt     1460 non-null   int64
#  7   RoofStyle     1460 non-null   str
#  8   BedroomAbvGr  1460 non-null   int64
#  9   KitchenAbvGr  1460 non-null   int64
#  10  SalePrice     1460 non-null   int64
# dtypes: int64(5), str(6)
# memory usage: 125.6 KB

# %%
df
# Out:
#      MSZoning  LotArea Street LotShape Utilities HouseStyle  YearBuilt  \
# 0          RL     8450   Pave      Reg    AllPub     2Story       2003
# 1          RL     9600   Pave      Reg    AllPub     1Story       1976
# 2          RL    11250   Pave      IR1    AllPub     2Story       2001
# 3          RL     9550   Pave      IR1    AllPub     2Story       1915
# 4          RL    14260   Pave      IR1    AllPub     2Story       2000
# ...       ...      ...    ...      ...       ...        ...        ...
# 1455       RL     7917   Pave      Reg    AllPub     2Story       1999
# 1456       RL    13175   Pave      Reg    AllPub     1Story       1978
# 1457       RL     9042   Pave      Reg    AllPub     2Story       1941
# 1458       RL     9717   Pave      Reg    AllPub     1Story       1950
# 1459       RL     9937   Pave      Reg    AllPub     1Story       1965
#
#      RoofStyle  BedroomAbvGr  KitchenAbvGr  SalePrice
# 0        Gable             3             1     208500
# 1        Gable             3             1     181500
# 2        Gable             3             1     223500
# 3        Gable             3             1     140000
# 4        Gable             4             1     250000
# ...        ...           ...           ...        ...
# 1455     Gable             3             1     175000
# 1456     Gable             3             1     210000
# 1457     Gable             4             1     266500
# 1458       Hip             2             1     142125
# 1459     Gable             3             1     147500
#
# [1460 rows x 11 columns]

# %%
df.describe()
# Out:
#              LotArea    YearBuilt  BedroomAbvGr  KitchenAbvGr      SalePrice
# count    1460.000000  1460.000000   1460.000000   1460.000000    1460.000000
# mean    10516.828082  1971.267808      2.866438      1.046575  180921.195890
# std      9981.264932    30.202904      0.815778      0.220338   79442.502883
# min      1300.000000  1872.000000      0.000000      0.000000   34900.000000
# 25%      7553.500000  1954.000000      2.000000      1.000000  129975.000000
# 50%      9478.500000  1973.000000      3.000000      1.000000  163000.000000
# 75%     11601.500000  2000.000000      3.000000      1.000000  214000.000000
# max    215245.000000  2010.000000      8.000000      3.000000  755000.000000

# %%
cat_cols = ['MSZoning', 'Street', 'LotShape', 'Utilities', 'HouseStyle', 'RoofStyle']

for col in cat_cols:
    labels = df[col].dropna().unique()
    mapping = {label: i for i, label in enumerate(labels)}
    df[col] = df[col].map(mapping)

# %%
df
# Out:
#       MSZoning  LotArea  Street  LotShape  Utilities  HouseStyle  YearBuilt  \
# 0            0     8450       0         0          0           0       2003
# 1            0     9600       0         0          0           1       1976
# 2            0    11250       0         1          0           0       2001
# 3            0     9550       0         1          0           0       1915
# 4            0    14260       0         1          0           0       2000
# ...        ...      ...     ...       ...        ...         ...        ...
# 1455         0     7917       0         0          0           0       1999
# 1456         0    13175       0         0          0           1       1978
# 1457         0     9042       0         0          0           0       1941
# 1458         0     9717       0         0          0           1       1950
# 1459         0     9937       0         0          0           1       1965
#
#       RoofStyle  BedroomAbvGr  KitchenAbvGr  SalePrice
# 0             0             3             1     208500
# 1             0             3             1     181500
# 2             0             3             1     223500
# 3             0             3             1     140000
# 4             0             4             1     250000
# ...         ...           ...           ...        ...
# 1455          0             3             1     175000
# 1456          0             3             1     210000
# 1457          0             4             1     266500
# 1458          1             2             1     142125
# 1459          0             3             1     147500
#
# [1460 rows x 11 columns]

# %%
df['MSZoning'].unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
df['Street'].unique()
# Out:
# array([0, 1])

# %%
df['LotShape'].unique()
# Out:
# array([0, 1, 2, 3])

# %%
df['Utilities'].unique()
# Out:
# array([0, 1])

# %%
df['HouseStyle'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
df['RoofStyle'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
df.head()
# Out:
#    MSZoning  LotArea  Street  LotShape  Utilities  HouseStyle  YearBuilt  \
# 0         0     8450       0         0          0           0       2003
# 1         0     9600       0         0          0           1       1976
# 2         0    11250       0         1          0           0       2001
# 3         0     9550       0         1          0           0       1915
# 4         0    14260       0         1          0           0       2000
#
#    RoofStyle  BedroomAbvGr  KitchenAbvGr  SalePrice
# 0          0             3             1     208500
# 1          0             3             1     181500
# 2          0             3             1     223500
# 3          0             3             1     140000
# 4          0             4             1     250000

# %%
df.hist()
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['SalePrice'], df['LotArea'])
ax.set_xlabel('SalePrice')
ax.set_ylabel('LotArea')
plt.show()

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c, cmap="RdYlGn", annot=True)
c
# Out:
#               MSZoning   LotArea    Street  LotShape  Utilities  HouseStyle  \
# MSZoning      1.000000 -0.161640  0.039678 -0.167918  -0.011167   -0.047199
# LotArea      -0.161640  1.000000  0.197131  0.315484   0.010123   -0.008187
# Street        0.039678  0.197131  1.000000  0.010129  -0.001682    0.025328
# LotShape     -0.167918  0.315484  0.010129  1.000000   0.026616   -0.067647
# Utilities    -0.011167  0.010123 -0.001682  0.026616   1.000000    0.076219
# HouseStyle   -0.047199 -0.008187  0.025328 -0.067647   0.076219    1.000000
# YearBuilt    -0.062684  0.014228 -0.021137  0.229365  -0.011505   -0.251479
# RoofStyle    -0.088537  0.137369  0.006881  0.043063  -0.011462    0.005490
# BedroomAbvGr -0.085901  0.119690 -0.028865  0.060028   0.004288   -0.097554
# KitchenAbvGr  0.073459 -0.017784 -0.013583 -0.094870  -0.005536    0.033279
# SalePrice    -0.116047  0.263843 -0.041036  0.267759  -0.014314   -0.188688
#
#               YearBuilt  RoofStyle  BedroomAbvGr  KitchenAbvGr  SalePrice
# MSZoning      -0.062684  -0.088537     -0.085901      0.073459  -0.116047
# LotArea        0.014228   0.137369      0.119690     -0.017784   0.263843
# Street        -0.021137   0.006881     -0.028865     -0.013583  -0.041036
# LotShape       0.229365   0.043063      0.060028     -0.094870   0.267759
# Utilities     -0.011505  -0.011462      0.004288     -0.005536  -0.014314
# HouseStyle    -0.251479   0.005490     -0.097554      0.033279  -0.188688
# YearBuilt      1.000000  -0.017865     -0.070651     -0.174800   0.522897
# RoofStyle     -0.017865   1.000000      0.001679     -0.011240   0.159332
# BedroomAbvGr  -0.070651   0.001679      1.000000      0.198597   0.168213
# KitchenAbvGr  -0.174800  -0.011240      0.198597      1.000000  -0.135907
# SalePrice      0.522897   0.159332      0.168213     -0.135907   1.000000

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['SalePrice'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['SalePrice'])
plt.show()

# %%
# Q1 = df['SalePrice'].quantile(0.25)
# Q3 = df['SalePrice'].quantile(0.75)
# IQR = Q3 - Q1

# df = df[(df['SalePrice'] >= Q1 - 1.5*IQR) & 
#         (df['SalePrice'] <= Q3 + 1.5*IQR)]

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c, cmap="RdYlGn", annot=True)
c
# Out:
#               MSZoning   LotArea    Street  LotShape  Utilities  HouseStyle  \
# MSZoning      1.000000 -0.161640  0.039678 -0.167918  -0.011167   -0.047199
# LotArea      -0.161640  1.000000  0.197131  0.315484   0.010123   -0.008187
# Street        0.039678  0.197131  1.000000  0.010129  -0.001682    0.025328
# LotShape     -0.167918  0.315484  0.010129  1.000000   0.026616   -0.067647
# Utilities    -0.011167  0.010123 -0.001682  0.026616   1.000000    0.076219
# HouseStyle   -0.047199 -0.008187  0.025328 -0.067647   0.076219    1.000000
# YearBuilt    -0.062684  0.014228 -0.021137  0.229365  -0.011505   -0.251479
# RoofStyle    -0.088537  0.137369  0.006881  0.043063  -0.011462    0.005490
# BedroomAbvGr -0.085901  0.119690 -0.028865  0.060028   0.004288   -0.097554
# KitchenAbvGr  0.073459 -0.017784 -0.013583 -0.094870  -0.005536    0.033279
# SalePrice    -0.116047  0.263843 -0.041036  0.267759  -0.014314   -0.188688
#
#               YearBuilt  RoofStyle  BedroomAbvGr  KitchenAbvGr  SalePrice
# MSZoning      -0.062684  -0.088537     -0.085901      0.073459  -0.116047
# LotArea        0.014228   0.137369      0.119690     -0.017784   0.263843
# Street        -0.021137   0.006881     -0.028865     -0.013583  -0.041036
# LotShape       0.229365   0.043063      0.060028     -0.094870   0.267759
# Utilities     -0.011505  -0.011462      0.004288     -0.005536  -0.014314
# HouseStyle    -0.251479   0.005490     -0.097554      0.033279  -0.188688
# YearBuilt      1.000000  -0.017865     -0.070651     -0.174800   0.522897
# RoofStyle     -0.017865   1.000000      0.001679     -0.011240   0.159332
# BedroomAbvGr  -0.070651   0.001679      1.000000      0.198597   0.168213
# KitchenAbvGr  -0.174800  -0.011240      0.198597      1.000000  -0.135907
# SalePrice      0.522897   0.159332      0.168213     -0.135907   1.000000

# %%
plt.boxplot(df['LotArea'])
plt.show()

# %%
Q1 = df['LotArea'].quantile(0.25)
Q3 = df['LotArea'].quantile(0.75)
IQR = Q3 - Q1

df = df[(df['LotArea'] >= Q1 - 1.5*IQR) & 
        (df['LotArea'] <= Q3 + 1.5*IQR)]

# %%
df.copy()
# Out:
#       MSZoning  LotArea  Street  LotShape  Utilities  HouseStyle  YearBuilt  \
# 0            3     8450       1         3          0           5       2003
# 1            3     9600       1         3          0           2       1976
# 2            3    11250       1         0          0           5       2001
# 3            3     9550       1         0          0           5       1915
# 4            3    14260       1         0          0           5       2000
# ...        ...      ...     ...       ...        ...         ...        ...
# 1455         3     7917       1         3          0           5       1999
# 1456         3    13175       1         3          0           2       1978
# 1457         3     9042       1         3          0           5       1941
# 1458         3     9717       1         3          0           2       1950
# 1459         3     9937       1         3          0           2       1965
#
#       RoofStyle  BedroomAbvGr  KitchenAbvGr  SalePrice
# 0             1             3             1     208500
# 1             1             3             1     181500
# 2             1             3             1     223500
# 3             1             3             1     140000
# 4             1             4             1     250000
# ...         ...           ...           ...        ...
# 1455          1             3             1     175000
# 1456          1             3             1     210000
# 1457          1             4             1     266500
# 1458          3             2             1     142125
# 1459          1             3             1     147500
#
# [1391 rows x 11 columns]

# %%
df['LotArea'].shape
# Out:
# (1391,)

# %%
x = df['LotArea'].values
y = df['SalePrice'].values

# mean
x_mean = np.mean(x)
y_mean = np.mean(y)

# slope & intercept
beta_1 = np.sum((x - x_mean)*(y - y_mean)) / np.sum((x - x_mean)**2)
beta_0 = y_mean - beta_1 * x_mean

# %%
df['SalePrice_Pred'] = beta_0 + beta_1 * df['LotArea']

# %%
df[['LotArea', 'SalePrice', 'SalePrice_Pred']]
# Out:
#       LotArea  SalePrice  SalePrice_Pred
# 0        8450     208500   169939.061184
# 1        9600     181500   182154.356230
# 2       11250     223500   199680.649122
# 3        9550     140000   181623.256445
# 4       14260     250000   231652.856155
# ...       ...        ...             ...
# 1455     7917     175000   164277.537480
# 1456    13175     210000   220127.990829
# 1457     9042     266500   176227.282634
# 1458     9717     142125   183397.129726
# 1459     9937     147500   185733.968778
#
# [1364 rows x 3 columns]

# %%
plt.figure()
plt.scatter(df['LotArea'], df['SalePrice'])
plt.plot(df['LotArea'], df['SalePrice_Pred'])
plt.xlabel('LotArea')
plt.ylabel('SalePrice')
plt.title('Linear Regression Manual: LotArea vs SalePrice')
plt.show()
