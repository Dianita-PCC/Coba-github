# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/PyAi/MalangTelkom/Student lifestyle data.csv')
df.head()
# Out:
#    Student_ID   Age  Gender   Department  CGPA  Sleep_Duration  Study_Hours  \
# 0        1001  22.0  Female      Science   NaN             7.3          3.3
# 1        1002  20.0    Male  Engineering  2.72             5.5          7.2
# 2        1003  20.0    Male      Medical   NaN             5.4          2.3
# 3        1004  21.0    Male  Engineering  3.63             8.1          2.0
# 4        1005  19.0    Male         Arts  3.14             6.8          2.6
#
#    Social_Media_Hours  Physical_Activity  Stress_Level
# 0                 3.4              114.0           5.0
# 1                 6.0                NaN           2.0
# 2                 1.8              137.0           3.0
# 3                 4.6              130.0           3.0
# 4                 4.3                4.0           6.0

# %%
df.shape
# Out:
# (100000, 10)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Student_ID               0
# Age                   1942
# Gender                1954
# Department            1949
# CGPA                  1954
# Sleep_Duration        1956
# Study_Hours           1953
# Social_Media_Hours    1955
# Physical_Activity     1953
# Stress_Level             0
# dtype: int64

# %%
df.dropna()
# Out:
#        Student_ID   Age  Gender  Department  CGPA  Sleep_Duration  \
# 3            1004  21.0     1.0         1.0  3.63             8.1
# 4            1005  19.0     1.0         3.0  3.14             6.8
# 5            1006  22.0     0.0         2.0  3.31             6.5
# 6            1007  18.0     1.0         0.0  2.14             4.4
# 8            1009  21.0     1.0         4.0  2.71             4.8
# ...           ...   ...     ...         ...   ...             ...
# 99993      100994  19.0     1.0         4.0  1.78             7.8
# 99994      100995  21.0     0.0         1.0  3.03             6.4
# 99996      100997  24.0     1.0         3.0  2.33             5.0
# 99997      100998  24.0     0.0         1.0  2.23             6.5
# 99999      101000  24.0     0.0         2.0  2.10             7.9
#
#        Study_Hours  Social_Media_Hours  Physical_Activity  Stress_Level
# 3              2.0                 4.6              130.0           3.0
# 4              2.6                 4.3                4.0           6.0
# 5              3.5                 4.1              129.0           2.0
# 6              4.0                 3.1               73.0           8.0
# 8              8.6                 0.3               82.0           5.0
# ...            ...                 ...                ...           ...
# 99993          4.3                 5.1               76.0           5.0
# 99994          5.1                 1.8              101.0           5.0
# 99996          3.6                 5.2              103.0           3.0
# 99997          5.8                 4.1               61.0           5.0
# 99999          3.5                 4.0               79.0           4.0
#
# [82962 rows x 10 columns]

# %%
df.shape
# Out:
# (97527, 10)

# %%
df.dtypes
# Out:
# Student_ID              int64
# Age                   float64
# Gender                float64
# Department            float64
# CGPA                  float64
# Sleep_Duration        float64
# Study_Hours           float64
# Social_Media_Hours    float64
# Physical_Activity     float64
# Stress_Level          float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 97527 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_ID          97527 non-null  int64
#  1   Age                 95585 non-null  float64
#  2   Gender              95573 non-null  float64
#  3   Department          95578 non-null  float64
#  4   CGPA                95573 non-null  float64
#  5   Sleep_Duration      95571 non-null  float64
#  6   Study_Hours         95574 non-null  float64
#  7   Social_Media_Hours  95572 non-null  float64
#  8   Physical_Activity   95574 non-null  float64
#  9   Stress_Level        97527 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 8.2 MB

# %%
df
# Out:
#        Student_ID   Age  Gender  Department  CGPA  Sleep_Duration  \
# 0            1001  22.0     0.0         0.0   NaN             7.3
# 1            1002  20.0     1.0         1.0  2.72             5.5
# 2            1003  20.0     1.0         2.0   NaN             5.4
# 3            1004  21.0     1.0         1.0  3.63             8.1
# 4            1005  19.0     1.0         3.0  3.14             6.8
# ...           ...   ...     ...         ...   ...             ...
# 99995      100996   NaN     0.0         2.0  2.02             7.0
# 99996      100997  24.0     1.0         3.0  2.33             5.0
# 99997      100998  24.0     0.0         1.0  2.23             6.5
# 99998      100999  19.0     NaN         1.0  3.61             6.1
# 99999      101000  24.0     0.0         2.0  2.10             7.9
#
#        Study_Hours  Social_Media_Hours  Physical_Activity  Stress_Level
# 0              3.3                 3.4              114.0           5.0
# 1              7.2                 6.0                NaN           2.0
# 2              2.3                 1.8              137.0           3.0
# 3              2.0                 4.6              130.0           3.0
# 4              2.6                 4.3                4.0           6.0
# ...            ...                 ...                ...           ...
# 99995          0.6                 1.4               66.0           4.0
# 99996          3.6                 5.2              103.0           3.0
# 99997          5.8                 4.1               61.0           5.0
# 99998          4.8                 4.9              116.0           4.0
# 99999          3.5                 4.0               79.0           4.0
#
# [97527 rows x 10 columns]

# %%
df.columns.tolist()
# Out:
# ['Student_ID',
#  'Age',
#  'Gender',
#  'Department',
#  'CGPA',
#  'Sleep_Duration',
#  'Study_Hours',
#  'Social_Media_Hours',
#  'Physical_Activity',
#  'Stress_Level']

# %%
cat_cols = ['Gender', 'Department']

for col in cat_cols:
    labels = df[col].dropna().unique()
    mapping = {label: i for i, label in enumerate(labels)}
    df[col] = df[col].map(mapping)

# %%
df
# Out:
#        Student_ID   Age  Gender  Department  CGPA  Sleep_Duration  \
# 0            1001  22.0     0.0         0.0   NaN             7.3
# 1            1002  20.0     1.0         1.0  2.72             5.5
# 2            1003  20.0     1.0         2.0   NaN             5.4
# 3            1004  21.0     1.0         1.0  3.63             8.1
# 4            1005  19.0     1.0         3.0  3.14             6.8
# ...           ...   ...     ...         ...   ...             ...
# 99995      100996   NaN     0.0         2.0  2.02             7.0
# 99996      100997  24.0     1.0         3.0  2.33             5.0
# 99997      100998  24.0     0.0         1.0  2.23             6.5
# 99998      100999  19.0     NaN         1.0  3.61             6.1
# 99999      101000  24.0     0.0         2.0  2.10             7.9
#
#        Study_Hours  Social_Media_Hours  Physical_Activity  Stress_Level
# 0              3.3                 3.4              114.0           5.0
# 1              7.2                 6.0                NaN           2.0
# 2              2.3                 1.8              137.0           3.0
# 3              2.0                 4.6              130.0           3.0
# 4              2.6                 4.3                4.0           6.0
# ...            ...                 ...                ...           ...
# 99995          0.6                 1.4               66.0           4.0
# 99996          3.6                 5.2              103.0           3.0
# 99997          5.8                 4.1               61.0           5.0
# 99998          4.8                 4.9              116.0           4.0
# 99999          3.5                 4.0               79.0           4.0
#
# [97527 rows x 10 columns]

# %%
plt.figure(figsize=(10,4))
c = df.corr(numeric_only=True)
sns.heatmap (c, cmap="RdYlGn", annot=True)
c
# Out:
#                     Student_ID       Age    Gender  Department      CGPA  \
# Student_ID            1.000000  0.000973  0.002332   -0.001889 -0.001798
# Age                   0.000973  1.000000 -0.002825    0.000619  0.002022
# Gender                0.002332 -0.002825  1.000000    0.001816 -0.006171
# Department           -0.001889  0.000619  0.001816    1.000000 -0.000534
# CGPA                 -0.001798  0.002022 -0.006171   -0.000534  1.000000
# Sleep_Duration        0.003892  0.001038  0.003526   -0.000674  0.015488
# Study_Hours           0.001363 -0.002687 -0.000007    0.007587  0.100909
# Social_Media_Hours   -0.002625 -0.000733  0.000950   -0.002000 -0.088527
# Physical_Activity     0.002871 -0.003088  0.003314    0.005503  0.003564
# Stress_Level         -0.006649  0.003142  0.001292   -0.002367 -0.012095
#
#                     Sleep_Duration  Study_Hours  Social_Media_Hours  \
# Student_ID                0.003892     0.001363           -0.002625
# Age                       0.001038    -0.002687           -0.000733
# Gender                    0.003526    -0.000007            0.000950
# Department               -0.000674     0.007587           -0.002000
# CGPA                      0.015488     0.100909           -0.088527
# Sleep_Duration            1.000000     0.003153           -0.002275
# Study_Hours               0.003153     1.000000            0.004371
# Social_Media_Hours       -0.002275     0.004371            1.000000
# Physical_Activity        -0.006993    -0.001835           -0.006028
# Stress_Level             -0.260751     0.007579            0.001581
#
#                     Physical_Activity  Stress_Level
# Student_ID                   0.002871     -0.006649
# Age                         -0.003088      0.003142
# Gender                       0.003314      0.001292
# Department                   0.005503     -0.002367
# CGPA                         0.003564     -0.012095
# Sleep_Duration              -0.006993     -0.260751
# Study_Hours                 -0.001835      0.007579
# Social_Media_Hours          -0.006028      0.001581
# Physical_Activity            1.000000     -0.290002
# Stress_Level                -0.290002      1.000000

# %%
corr = df.corr(numeric_only=True)
corr['Stress_Level'].sort_values(ascending=False)
# Out:
# Stress_Level          1.000000
# Study_Hours           0.007579
# Age                   0.003142
# Social_Media_Hours    0.001581
# Gender                0.001292
# Department           -0.002367
# Student_ID           -0.006649
# CGPA                 -0.012095
# Sleep_Duration       -0.260751
# Physical_Activity    -0.290002
# Name: Stress_Level, dtype: float64

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['Stress_Level'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['Stress_Level'])
plt.show()

# %%
sns.boxplot(x=df['Stress_Level'])
# Out:
# <Axes: xlabel='Stress_Level'>

# %%
Q1 = df['Stress_Level'].quantile(0.25)
Q3 = df['Stress_Level'].quantile(0.75)
IQR = Q3 - Q1

df = df[(df['Stress_Level'] >= Q1 - 1.5*IQR) &
        (df['Stress_Level'] <= Q3 + 1.5*IQR)]

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['Physical_Activity'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['Physical_Activity'])
plt.show()

# %%
sns.boxplot(x=df['Physical_Activity'])
# Out:
# <Axes: xlabel='Physical_Activity'>

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['Stress_Level'], df['Sleep_Duration'])
ax.set_xlabel('Sleep_Duration')
ax.set_ylabel('Stress_Level')
plt.show()

# %% [markdown]
# # Physical_Activity

# %%
df.dropna()
# Out:
#        Student_ID   Age  Gender  Department  CGPA  Sleep_Duration  \
# 3            1004  21.0     1.0         1.0  3.63             8.1
# 4            1005  19.0     1.0         3.0  3.14             6.8
# 5            1006  22.0     0.0         2.0  3.31             6.5
# 6            1007  18.0     1.0         0.0  2.14             4.4
# 8            1009  21.0     1.0         4.0  2.71             4.8
# ...           ...   ...     ...         ...   ...             ...
# 99993      100994  19.0     1.0         4.0  1.78             7.8
# 99994      100995  21.0     0.0         1.0  3.03             6.4
# 99996      100997  24.0     1.0         3.0  2.33             5.0
# 99997      100998  24.0     0.0         1.0  2.23             6.5
# 99999      101000  24.0     0.0         2.0  2.10             7.9
#
#        Study_Hours  Social_Media_Hours  Physical_Activity  Stress_Level
# 3              2.0                 4.6              130.0           3.0
# 4              2.6                 4.3                4.0           6.0
# 5              3.5                 4.1              129.0           2.0
# 6              4.0                 3.1               73.0           8.0
# 8              8.6                 0.3               82.0           5.0
# ...            ...                 ...                ...           ...
# 99993          4.3                 5.1               76.0           5.0
# 99994          5.1                 1.8              101.0           5.0
# 99996          3.6                 5.2              103.0           3.0
# 99997          5.8                 4.1               61.0           5.0
# 99999          3.5                 4.0               79.0           4.0
#
# [82962 rows x 10 columns]

# %%
def train_test_split_np(X, y, test_size=0.2, seed=42):
    np.random.seed(seed) 
    idx = np.arange(len(X))
    np.random.shuffle(idx)
    
    n_test = int(len(X) * test_size)
    test_idx = idx[:n_test]
    train_idx = idx[n_test:]
    
    return X[train_idx], X[test_idx], y[train_idx], y[test_idx]

X = df["Physical_Activity"].to_numpy()
y = df["Stress_Level"].to_numpy()

X_train, X_test, y_train, y_test = train_test_split_np(X, y)

print("Train:", len(X_train))
print("Test:", len(X_test))
# Out:
# Train: 78022
# Test: 19505

# %%
mean_x = np.mean(X_train)
mean_y = np.mean(y_train)

numerator = np.sum((X_train - mean_x) * (y_train - mean_y))
denominator = np.sum((X_train - mean_x)) ** 2

b1 = numerator / denominator
b0 = mean_y - b1 * mean_x

print("Slope (b1):", b1)
print("Intercept (b0):", b0)
# Out:
# Slope (b1): nan
# Intercept (b0): nan

# %%
#rumus pred
y_pred = b0 + b1 * X_test

# %%
#eval
def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))
    
def mse(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true,y_pred))

def r2(y_true,y_pred):
    ss_total = np.sum((y_true - np.mean(y_true))**2)
    ss_res = np.sum((y_true - y_pred)**2)
    return 1 - (ss_res/ss_total)

print("MAE:", mae(y_test,y_pred))
print("MSE:", mse(y_test,y_pred))
print("RMSE:", rmse(y_test,y_pred))
print("R2 Score:", r2(y_test,y_pred))
# Out:
# MAE: nan
# MSE: nan
# RMSE: nan
# R2 Score: nan
